# %%
from lazylib import make, AlexNet, device, takeConfusionMatrix, takeRocCurve, now, register
import torch

# %%
n = now()
epocs = 4
model, metrics = make(
    EPOCHS=epocs, 
    BATCH_SIZE=128, 
    LEARNING_RATE=1e-3, 
    csv_path="../../../data/processed/csv/nslClean.csv", 
    MODEL=AlexNet(x=128).to(device()), 
    SEED=1701,
    xcol=2
    ) 
register(metrics, f"/home/luizp/projects/pibit/src/0utput/text/{n}.txt")
torch.save(model.state_dict(), f"/home/luizp/projects/pibit/src/0utput/models/{n}_alexnet_{epocs}.nnModel")
# Out:
# [13-02-2024 14-15-37] Epoch 001 Acc: 0.9040 Loss: 0.21999819: 100%|██████████| 99/99 [00:02<00:00, 43.90it/s]
# [13-02-2024 14-15-45] Epoch 001 Val. Acc: 0.9603 Val. Loss: 0.11142171: 100%|██████████| 886/886 [00:07<00:00, 118.04it/s]
# [60291  4146   359 48578]
# [13-02-2024 14-15-47] Epoch 002 Acc: 0.9659 Loss: 0.10320798: 100%|██████████| 99/99 [00:02<00:00, 47.11it/s]
# [13-02-2024 14-15-55] Epoch 002 Val. Acc: 0.9687 Val. Loss: 0.08844104: 100%|██████████| 886/886 [00:07<00:00, 112.61it/s]
# [60251  3147   399 49577]
# [13-02-2024 14-15-58] Epoch 003 Acc: 0.9701 Loss: 0.08649232: 100%|██████████| 99/99 [00:02<00:00, 47.53it/s]
# [13-02-2024 14-16-06] Epoch 003 Val. Acc: 0.9632 Val. Loss: 0.10615126: 100%|██████████| 886/886 [00:07<00:00, 111.40it/s]
# [59421  2941  1229 49783]
# [13-02-2024 14-16-08] Epoch 004 Acc: 0.9706 Loss: 0.08134016: 100%|██████████| 99/99 [00:02<00:00, 48.27it/s]
# [13-02-2024 14-16-18] Epoch 004 Val. Acc: 0.9704 Val. Loss: 0.08360795: 100%|██████████| 886/886 [00:09<00:00, 89.18it/s]
# [60381  3087   269 49637]
# Finished experiment!

# %%
cm = takeConfusionMatrix(metrics, epocs-1, f"/home/luizp/projects/pibit/src/0utput/img/confusionMatix/{n}.png")

# %%
takeRocCurve(metrics, epocs-1, f"/home/luizp/projects/pibit/src/0utput/img/rocCurve/{n}.png")
